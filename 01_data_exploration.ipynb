# %%
# !pip install matplotlib seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: to display plots inline in the notebook
# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# 1) Load the CSV:
df = pd.read_csv('data/spotify-2023 2.csv')

  # Adjust path if needed

# 2) Check first 5 rows:
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# Total missing values
print("Missing values per column:\n", df.isnull().sum())

# Percentage of missing data
nan_percent = df.isnull().mean() * 100
print("\nPercentage of missing values:\n", nan_percent)
# Out:
# Missing values per column:
#  track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64
#
# Percentage of missing values:
#  track_name              0.00000
# artist(s)_name          0.00000
# artist_count            0.00000
# released_year           0.00000
# released_month          0.00000
# released_day            0.00000
# ...

# %%
# Check the data type
print("Data type of in_shazam_charts:", df['in_shazam_charts'].dtype)

# Look at unique values
print("\nUnique values in in_shazam_charts:")
print(df['in_shazam_charts'].unique())
# Out:
# Data type of in_shazam_charts: object
#
# Unique values in in_shazam_charts:
# ['826' '382' '949' '548' '425' '946' '418' '194' '953' '339' '251' '168'
#  '1,021' '1,281' nan '187' '0' '1,173' '29' '150' '73' '139' '1,093' '96'
#  '211' '325' '294' '197' '27' '310' '354' '184' '212' '81' '82' '100' '62'
#  '69' '727' '311' '1,133' '102' '332' '259' '140' '16' '110' '810' '176'
#  '615' '210' '216' '215' '167' '37' '171' '272' '529' '26' '5' '169' '230'
#  '84' '154' '93' '115' '72' '8' '323' '49' '1,451' '1,170' '429' '162'
#  '10' '478' '236' '200' '78' '266' '486' '204' '34' '202' '312' '32' '153'
#  '519' '458' '48' '666' '14' '925' '88' '203' '44' '74' '638' '64' '71'
#  '2' '3' '136' '148' '22' '368' '1' '189' '52' '9' '31' '66' '208' '28'
#  '558' '195' '13' '60' '503' '56' '15' '454' '40' '285' '129' '58' '117'
#  '47' '20' '30' '80' '263' '116' '57' '39' '111' '7' '166' '19' '99' '51'
#  '109' '42' '33' '675' '348' '36' '240' '113' '6' '23' '4' '182' '54'
# ...

# %%
# Remove commas and convert to numeric
df['in_shazam_charts'] = df['in_shazam_charts'].str.replace(',', '')
df['in_shazam_charts'] = pd.to_numeric(df['in_shazam_charts'], errors='coerce')

# Fill NaNs with the median
df['in_shazam_charts'] = df['in_shazam_charts'].fillna(df['in_shazam_charts'].median())

# %%
print(df['in_shazam_charts'].dtype)
print(df['in_shazam_charts'].isnull().sum())
# Out:
# float64
# 0

# %%
# Drop any rows where *all* columns are NaN
df = df.dropna(how='all')
df.shape  # should show fewer rows now
df.tail()  # confirm no all-NaN rows remain
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# Find any row where 'streams' has that weird string pattern
df[df['streams'].astype(str).str.contains('BPM', na=False)]

df = df.drop(index=574)
df[df['streams'].astype(str).str.contains('BPM', na=False)]

df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# %%
# Drop any row where any column contains the string 'BPM'
df = df[~df.astype(str).apply(lambda row: row.str.contains('BPM', na=False)).any(axis=1)]
# This should return 0 rows
df[df.astype(str).apply(lambda row: row.str.contains('BPM', na=False)).any(axis=1)]
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['streams_normalized'] = scaler.fit_transform(df[['streams']])

# %%
df[['streams', 'streams_normalized']].head(10)
# Out:
#      streams  streams_normalized
# 0  141381703            0.038170
# 1  133716286            0.036101
# 2  140003974            0.037798
# 3  800840817            0.216215
# 4  303236322            0.081869
# 5  183706234            0.049597
# 6  725980112            0.196004
# 7   58149378            0.015699
# 8   95217315            0.025707
# 9  553634067            0.149473
